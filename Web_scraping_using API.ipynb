# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests

api_key = '4b7647598f8ac3bf01f8419719d4bec8'
#lat = 28.2719
#lon = 83.5891
#url = f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}&units=metric'
city='Pokhara'
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric'

response = requests.get(url)
data = response.json()

# %%
# Extract key fields
weather_main = data['weather'][0]['main']
weather_desc = data['weather'][0]['description']
temperature = data['main']['temp']
feels_like = data['main']['feels_like']
humidity = data['main']['humidity']
pressure = data['main']['pressure']
wind_speed = data['wind']['speed']
city = data['name']

# %%
data
# Out:
# {'coord': {'lon': 83.9833, 'lat': 28.2333},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 21.03,
#   'feels_like': 20.73,
#   'temp_min': 21.03,
#   'temp_max': 21.03,
#   'pressure': 1010,
#   'humidity': 59,
#   'sea_level': 1010,
#   'grnd_level': 869},
#  'visibility': 10000,
#  'wind': {'speed': 1.54, 'deg': 8, 'gust': 1.52},
#  'clouds': {'all': 99},
#  'dt': 1746284265,
#  'sys': {'country': 'NP', 'sunrise': 1746229338, 'sunset': 1746277169},
#  'timezone': 20700,
#  'id': 1282898,
#  'name': 'Pokhara',
#  'cod': 200}

# %%
# Create DataFrame
weather_df = pd.DataFrame([{
    'City': city,
    'Weather': weather_main,
    'Description': weather_desc,
    'Temperature (°C)': temperature,
    'Feels Like (°C)': feels_like,
    'Humidity (%)': humidity,
    'Pressure (hPa)': pressure,
    'Wind Speed (m/s)': wind_speed
}])

# %%
weather_df
# Out:
#       City Weather      Description  Temperature (°C)  Feels Like (°C)  \
# 0  Pokhara  Clouds  overcast clouds             21.03            20.73
#
#    Humidity (%)  Pressure (hPa)  Wind Speed (m/s)
# 0            59            1010              1.54
